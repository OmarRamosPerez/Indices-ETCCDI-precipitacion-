# %% [markdown]
# ## Índices ETCCDI de Precipitación —
# # Percentiles
#
# | ID | Nombre | Definición | Unidades |
# |-----------|----|--------|------------|
# |**R95p**| Días muy húmedos | Precip. total anual o estacional acumulada en días > percentil 95 | mm |
# |**R99p**| Días extremadamente húmedos | Precip. total anual o estacional acumulada en días > percentil 99 | mm |

# %% [markdown]
# ## Ploteo in situ — ETCCDI_precip_plot_in_situ
#
# Las funciones generan gráficas de series temporales a partir de los archivos .xlsx producidos en la Notebook % run Indices_percentiles_in_situ.ipynb.
#
# - Entrada: Un archivo .xlsx
#
# **Formato del archivo .xlsx de entrada:**
# ```
# Year  R95p (mm)
# 1936    0
# 1937    0
# 1938    0
# ...
# ```
#
# - Ruta de salida de Figura: Donde se guardará la figura del índice correspondiente.
# - Ruta de salida de Estadísticos: Donde se guardará un archivo .xlsx con (Kendall_tau,p_value, Tendencia, etc.)

# %% [markdown]
# ## Índice R95p (Precipitación en días muy húmedos (> percentil 95))

# %%
# ── Módulo de graficamiento ──────────────────────────────────────────────────
from ETCCDI_precipitacion import ETCCDI_precip_plot_in_situ

# %%
# ── Rutas de la estación  (ajusta según tu estructura de datos)────────────────────────────────────────────────────────
ARCHIVO_INDICE = '/home/omar/Documents/Indices_Precip/Indices_Percentiles/RP95_sydney_observatory_hill.xlsx'
salida_figura = '/home/omar/Documents/Indices_Precip/Figuras/Indices_Percentiles/RP95_sydney_observatory_hill.png'

salida_excel = "/home/omar/Documents/Indices_Precip/Estadisticas/Indices_Percentiles/RP95_sydney_observatory_hill.xlsx"

# %%
# Gráfica de la serie temporal de RP95 con tendencia
ETCCDI_precip_plot_in_situ.plot(
    ARCHIVO_INDICE,
    salida_figura,
    salida_excel
)
# Out:
# ********************
# ✅Figura guardada correctamente: /home/omar/Documents/Indices_Precip/Figuras/Indices_Percentiles/RP95_sydney_observatory_hill.png
# ********************
# ********************
# ✅ Archivo de estadísticas exportado: /home/omar/Documents/Indices_Precip/Estadisticas/Indices_Percentiles/RP95_sydney_observatory_hill.xlsx
# ********************
# ([{'Kendall_tau': np.float64(-0.01930379746835443),
#    'p_value': np.float64(0.8031443980457138),
#    'Tendencia': 'no trend',
#    'Z-statistic': np.float64(-0.24927974497402572),
#    'Sen_slope': np.float64(0.0),
#    'IC_inferior': np.float64(0.0),
#    'IC_superior': np.float64(0.0),
#    'Intercept': np.float64(0.0)}],
#     Kendall_tau   p_value Tendencia  Z-statistic  Sen_slope  IC_inferior  \
#  0    -0.019304  0.803144  no trend     -0.24928        0.0          0.0
#
#     IC_superior  Intercept
#  0          0.0        0.0  )
