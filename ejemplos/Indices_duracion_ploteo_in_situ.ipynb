# %% [markdown]
# ## Índices ETCCDI de Precipitación-
# ##  Duración
#
# | ID | Nombre | Definición | Unidades |
# |----|--------|------------|----------|
# |**CDD**| Días secos consecutivos |	Máx. número de días consecutivos cuando PR < 1 mm |	días |
# |**CWD**| Días húmedos consecutivos | Máx. número de días consecutivos cuando PR ≥ 1 mm	| días |

# %% [markdown]
# ## Ploteo in situ — ETCCDI_precip_plot_in_situ
#
# Las funciones generan gráficas de series temporales a partir de los archivos .xlsx producidos en la Notebook % run Indices_frecuencia_in_situ.ipynb.
#
#
# - Entrada: Un archivo .xlsx
#
# **Formato del archivo `.xlsx` de entrada:**
# ```
# Year  Indice_cdd
# 1936    14
# 1937    23
# 1938    23
# ...
# ```
#
# - Ruta de salida de Figura: Donde se guardará la figura del índice correspondiente.
# - Ruta de salida de Estadísticos: Donde se guardará un archivo .xlsx con  (Kendall_tau,p_value, Tendencia, etc.)

# %% [markdown]
# ## Índice CDD (Días secos (PR < 1 mm) consecutivos)

# %% [markdown]
# ## Importando el Módulo de ploteo ──────────────────────────────────────────────────

# %%
from ETCCDI_precipitacion import ETCCDI_precip_plot_in_situ

# %%
# ── Rutas de la estación  (ajusta según tu estructura de datos)────────────────────────────────────────────────────────
ARCHIVO_INDICE = '/home/omar/Documents/Indices_Precip/Indices_Duracion/CDD_sydney_observatory_hill.xlsx'
salida_figura = '/home/omar/Documents/Indices_Precip/Figuras/Indices_Duracion/CDD_sydney_observatory_hill.png'
salida_excel = "/home/omar/Documents/Indices_Precip/Estadisticas/Indices_Duracion/CDD_sydney_observatory_hill.xlsx"

# %%
# Gráfica de la serie temporal de CDD con tendencia
ETCCDI_precip_plot_in_situ.plot(
    ARCHIVO_INDICE,
    salida_figura,
    salida_excel
)
# Out:
# ********************
# ✅Figura guardada correctamente: /home/omar/Documents/Indices_Precip/Figuras/Indices_Duracion/CDD_sydney_observatory_hill.png
# ********************
# ********************
# ✅ Archivo de estadísticas exportado: /home/omar/Documents/Indices_Precip/Estadisticas/Indices_Duracion/CDD_sydney_observatory_hill.xlsx
# ********************
# ([{'Kendall_tau': np.float64(-0.02120253164556962),
#    'p_value': np.float64(0.7839249961240531),
#    'Tendencia': 'no trend',
#    'Z-statistic': np.float64(-0.2742077194714283),
#    'Sen_slope': np.float64(0.0),
#    'IC_inferior': np.float64(-0.0625),
#    'IC_superior': np.float64(0.04),
#    'Intercept': np.float64(20.0)}],
#     Kendall_tau   p_value Tendencia  Z-statistic  Sen_slope  IC_inferior  \
#  0    -0.021203  0.783925  no trend    -0.274208        0.0      -0.0625
#
#     IC_superior  Intercept
#  0         0.04       20.0  )

# %% [markdown]
# ## [Índice Tutorial](Indice.md)
