# %% [markdown]
# ## Índices ETCCDI de Precipitación-
# ##  Frecuencia
#
# | ID | Nombre | Definición | Unidades |
# |----|--------|------------|----------|
# |**R10mm**| Número de días de precipitación intensa | Conteo anual o estacional cuando PR ≥ 10 mm/año | días |
# |**R20mm**| Número de días de precipitación muy intensa | Conteo anual o estacional cuando con PR ≥ 20 mm/año | días |

# %% [markdown]
# ## Ploteo in situ — ETCCDI_precip_plot_in_situ
#
# Las funciones generan gráficas de series temporales a partir de los archivos .xlsx producidos en la Notebook % run Indices_frecuencia_in_situ.ipynb.
#
#
# - Entrada: Un archivo .xlsx
#
# **Formato del archivo `.xlsx` de entrada:**
# ```
# Year  Indice_R10mm
# 1936    21
# 1937    40
# 1938    29
# ...
# ```
#
# - Ruta de salida de Figura: Donde se guardará la figura del índice correspondiente.
# - Ruta de salida de Estadísticos: Donde se guardará un archivo .xlsx con  (Kendall_tau,p_value, Tendencia, etc.)

# %% [markdown]
# ## Importando el Módulo de ploteo ──────────────────────────────────────────────────

# %%
from ETCCDI_precipitacion import ETCCDI_precip_plot_in_situ

# %% [markdown]
# ## Índice R10mm (Número de días de precipitación intensa)

# %%
# ── Rutas de la estación  (ajusta según tu estructura de datos)────────────────────────────────────────────────────────
ARCHIVO_INDICE = '/home/omar/Documents/Indices_Precip/Indices_Frecuencia/R10mm_sydney_observatory_hill.xlsx'
salida_figura = '/home/omar/Documents/Indices_Precip/Figuras/Indices_Frecuencia/R10mm_sydney_observatory_hill.png'
salida_excel = "/home/omar/Documents/Indices_Precip/Estadisticas/Indices_Frecuencia/R10mm_sydney_observatory_hill.xlsx"

# %%
# Gráfica de la serie temporal de R10mm con tendencia
ETCCDI_precip_plot_in_situ.plot(
    ARCHIVO_INDICE,
    salida_figura,
    salida_excel
)
# Out:
# ********************
# ✅Figura guardada correctamente: /home/omar/Documents/Indices_Precip/Figuras/Indices_Frecuencia/R10mm_sydney_observatory_hill.png
# ********************
# ********************
# ✅ Archivo de estadísticas exportado: /home/omar/Documents/Indices_Precip/Estadisticas/Indices_Frecuencia/R10mm_sydney_observatory_hill.xlsx
# ********************
# ([{'Kendall_tau': np.float64(0.08291139240506329),
#    'p_value': np.float64(0.2782021577961544),
#    'Tendencia': 'no trend',
#    'Z-statistic': np.float64(1.0843668906370119),
#    'Sen_slope': np.float64(0.038461538461538464),
#    'IC_inferior': np.float64(-0.03225806451612903),
#    'IC_superior': np.float64(0.1276595744680851),
#    'Intercept': np.float64(-43.48076923076924)}],
#     Kendall_tau   p_value Tendencia  Z-statistic  Sen_slope  IC_inferior  \
#  0     0.082911  0.278202  no trend     1.084367   0.038462    -0.032258
#
#     IC_superior  Intercept
#  0      0.12766 -43.480769  )

# %% [markdown]
# ## índice R20mm (Número de días de precipitación muy intensa)

# %%
# ── Rutas de la estación  (ajusta según tu estructura de datos)────────────────────────────────────────────────────────
ARCHIVO_INDICE = '/home/omar/Documents/Indices_Precip/Indices_Frecuencia/R20mm_sydney_observatory_hill.xlsx'
SALIDA_FIGURA = '/home/omar/Documents/Indices_Precip/Figuras/Indices_Frecuencia/R20mm_sydney_observatory_hill.png'
SALIDA_EXCEL  = '/home/omar/Documents/Indices_Precip/Estadisticas/Indices_Frecuencia/R20mm_sydney_observatory_hill.xlsx'

# %%
ETCCDI_precip_plot_in_situ.plot(
    ARCHIVO_INDICE,
    SALIDA_FIGURA,
    SALIDA_EXCEL
)
# Out:
# ********************
# ✅Figura guardada correctamente: /home/omar/Documents/Indices_Precip/Figuras/Indices_Frecuencia/R20mm_sydney_observatory_hill.png
# ********************
# ********************
# ✅ Archivo de estadísticas exportado: /home/omar/Documents/Indices_Precip/Estadisticas/Indices_Frecuencia/R20mm_sydney_observatory_hill.xlsx
# ********************
# ([{'Kendall_tau': np.float64(-0.014556962025316455),
#    'p_value': np.float64(0.851692145237523),
#    'Tendencia': 'no trend',
#    'Z-statistic': np.float64(-0.1869598087305193),
#    'Sen_slope': np.float64(0.0),
#    'IC_inferior': np.float64(-0.0625),
#    'IC_superior': np.float64(0.05405405405405406),
#    'Intercept': np.float64(16.0)}],
#     Kendall_tau   p_value Tendencia  Z-statistic  Sen_slope  IC_inferior  \
#  0    -0.014557  0.851692  no trend     -0.18696        0.0      -0.0625
#
#     IC_superior  Intercept
#  0     0.054054       16.0  )
