# %% [markdown]
# ## Índices ETCCDI de Precipitación-
# ##  Duración
#
# | ID | Nombre | Definición | Unidades |
# |----|--------|------------|----------|
# |**CDD**| Días secos consecutivos |	Máx. número de días consecutivos cuando PR < 1 mm |	días |
# |**CWD**| Días húmedos consecutivos | Máx. número de días consecutivos cuando PR ≥ 1 mm	| días |

# %% [markdown]
# ## Datos In Situ
# Las funciones para calcular los índices Categoria Duración
# Trabajan con datos de estaciones meteorológicas en formato .txt.
#
# - Entrada: Un archivo .txt
#
# **Formato del archivo `.txt` de entrada:**
# ```
# Year  Month  Day   PR     TX     TN
# 1991    1     1   -99.9   25.3   12.1
# 1991    1     2    0.0    26.1   13.4
# ...
# ```
# Columnas separadas por espacios\
# `PR`: precipitación (mm), `TX`: temp. máxima (°C), `TN`: temp. mínima (°C)\
# Valor faltante: `-99.9`
#
#
# - Ruta de salida: Donde el índice calculado se exporta como archivo `.xlsx`.\
# **Formato esperado del archivo de salida:** \
# ```
# Year   Índice

# %% [markdown]
# ## Índice CDD (Días secos (PR < 1 mm) consecutivos)

# %% [markdown]
# ## Importando módulos de procesamiento -Datos en In Situ-

# %%
from ETCCDI_precipitacion import ETCCDI_precip_in_situ

# %%
# ── Rutas ** ajusta según tu estructura de datos *** ────────────────────────────────────────────────────
ARCHIVO_ESTACION = '/home/omar/Documents/Indices_Precip/Datos_entrada/sydney_observatory_hill_1936-2015.txt'
SALIDA_INDICE_INSITU = '/home/omar/Documents/Indices_Precip/Indices_Duracion/CDD_sydney_observatory_hill.xlsx'

# %%
ETCCDI_precip_in_situ.cdd(
    ARCHIVO_ESTACION,
    SALIDA_INDICE_INSITU,
)
# Out:
# **************************
# ✅ Índice CDD ejecutado exitosamente. Archivo guardado: /home/omar/Documents/Indices_Precip/Indices_Duracion/CDD_sydney_observatory_hill.xlsx
# **************************

# %% [markdown]
# ## Índice CWD (Días húmedos (PR ≥ 1 mm) consecutivos)

# %%
from ETCCDI_precipitacion import ETCCDI_precip_in_situ

# %%
# ── Rutas ** ajusta según tus directorios y archivos *** ────────────────────────────────────────────────────
ARCHIVO_ESTACION = '/home/omar/Documents/Indices_Precip/Datos_entrada/sydney_observatory_hill_1936-2015.txt'
SALIDA_INDICE_INSITU = '/home/omar/Documents/Indices_Precip/Indices_Duracion/CWD_sydney_observatory_hill.xlsx'

# %%
ETCCDI_precip_in_situ.cwd(
    ARCHIVO_ESTACION,
    SALIDA_INDICE_INSITU,
)
# Out:
# **************************
# ✅ Índice CWD ejecutado exitosamente. Archivo guardado: /home/omar/Documents/Indices_Precip/Indices_Duracion/CWD_sydney_observatory_hill.xlsx
# **************************

# %% [markdown]
# ## [Índice Tutorial](Indice.md)
